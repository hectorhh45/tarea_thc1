# %% [markdown]
# <a href="https://colab.research.google.com/github/hectorhh45/tarea_thc1/blob/main/Espa%C3%B1a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
link= 'https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code = '?raw=true'
url = link+code
df = pd.read_csv(url,sep=',',index_col=1)

# %%
df
# Out:
#                              Country  No. of confirmed cases  \
# Date
# 29/08/2014                    Guinea                     482
# 29/08/2014                   Nigeria                      15
# 29/08/2014              Sierra Leone                     935
# 29/08/2014                   Liberia                     322
# 05/09/2014                    Guinea                     604
# ...                              ...                     ...
# 23/03/2016                   Liberia                    3151
# 23/03/2016                     Italy                       1
# 23/03/2016                   Liberia                       2
# 23/03/2016                   Nigeria                      19
# 23/03/2016  United States of America                       4
#
#             No. of confirmed deaths  Male Cases  Female Cases    Boys   Girls  \
# Date
# 29/08/2014                    287.0       289.2         192.8   86.76   57.84
# 29/08/2014                      6.0         9.0           6.0    2.70    1.80
# 29/08/2014                    380.0       561.0         374.0  168.30  112.20
# 29/08/2014                    225.0       193.2         128.8   57.96   38.64
# 05/09/2014                    362.0       362.4         241.6  108.72   72.48
# ...                             ...         ...           ...     ...     ...
# 23/03/2016                      NaN      1890.6        1260.4  567.18  378.12
# 23/03/2016                      NaN         0.6           0.4    0.18    0.12
# 23/03/2016                      1.0         1.2           0.8    0.36    0.24
# 23/03/2016                      7.0        11.4           7.6    3.42    2.28
# 23/03/2016                      1.0         2.4           1.6    0.72    0.48
#
#             Adult Male  Adult Female  Old Male  Old Female
# Date
# 29/08/2014      173.52        115.68     28.92       19.28
# 29/08/2014        5.40          3.60      0.90        0.60
# 29/08/2014      336.60        224.40     56.10       37.40
# 29/08/2014      115.92         77.28     19.32       12.88
# 05/09/2014      217.44        144.96     36.24       24.16
# ...                ...           ...       ...         ...
# 23/03/2016     1134.36        756.24    189.06      126.04
# 23/03/2016        0.36          0.24      0.06        0.04
# 23/03/2016        0.72          0.48      0.12        0.08
# 23/03/2016        6.84          4.56      1.14        0.76
# 23/03/2016        1.44          0.96      0.24        0.16
#
# [2484 rows x 11 columns]

# %%
# !pip install skforecast
# Out:
# Requirement already satisfied: skforecast in /usr/local/lib/python3.10/dist-packages (0.11.0)
# Requirement already satisfied: numpy<1.27,>=1.20 in /usr/local/lib/python3.10/dist-packages (from skforecast) (1.23.5)
# Requirement already satisfied: pandas<2.2,>=1.2 in /usr/local/lib/python3.10/dist-packages (from skforecast) (1.5.3)
# Requirement already satisfied: tqdm<4.67,>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from skforecast) (4.66.1)
# Requirement already satisfied: scikit-learn<1.4,>=1.0 in /usr/local/lib/python3.10/dist-packages (from skforecast) (1.2.2)
# Requirement already satisfied: optuna<3.5,>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from skforecast) (3.4.0)
# Requirement already satisfied: joblib<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from skforecast) (1.3.2)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna<3.5,>=2.10.0->skforecast) (1.12.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna<3.5,>=2.10.0->skforecast) (6.7.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna<3.5,>=2.10.0->skforecast) (23.2)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna<3.5,>=2.10.0->skforecast) (2.0.23)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna<3.5,>=2.10.0->skforecast) (6.0.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.2,>=1.2->skforecast) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.2,>=1.2->skforecast) (2023.3.post1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<1.4,>=1.0->skforecast) (1.11.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<1.4,>=1.0->skforecast) (3.2.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna<3.5,>=2.10.0->skforecast) (1.3.0)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna<3.5,>=2.10.0->skforecast) (4.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas<2.2,>=1.2->skforecast) (1.16.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna<3.5,>=2.10.0->skforecast) (3.0.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna<3.5,>=2.10.0->skforecast) (2.1.3)

# %%
cuantos=df.groupby("Country").size().reset_index(name="cuantos")
cuantos
# Out:
#                     Country  cuantos
# 0                    Guinea      259
# 1                     Italy      141
# 2                   Liberia      364
# 3                      Mali      243
# 4                   Nigeria      255
# 5                   Senegal      254
# 6              Sierra Leone      259
# 7                     Spain      243
# 8            United Kingdom      221
# 9  United States of America      245

# %%
plt.pie(cuantos["cuantos"],labels=cuantos["Country"],autopct="%0.1f %%")
plt.axis("equal")
plt.title("Distribución del ébola por países")
plt.savefig("Pastel_Países.png",dpi=300,format="png")
plt.show()

# %% [markdown]
# ### **ESPAÑA**

# %%
df['Country']=="Spain"
# Out:
# Date
# 29/08/2014    False
# 29/08/2014    False
# 29/08/2014    False
# 29/08/2014    False
# 05/09/2014    False
#               ...
# 23/03/2016    False
# 23/03/2016    False
# 23/03/2016    False
# 23/03/2016    False
# 23/03/2016    False
# Name: Country, Length: 2484, dtype: bool

# %%
ESP=df[df['Country']=="Spain"]
ESP
# Out:
#            Country  No. of confirmed cases  No. of confirmed deaths  \
# Date
# 10/10/2014   Spain                       1                      0.0
# 15/10/2014   Spain                       1                      0.0
# 17/10/2014   Spain                       1                      0.0
# 22/10/2014   Spain                       1                      0.0
# 25/10/2014   Spain                       1                      0.0
# ...            ...                     ...                      ...
# 17/12/2015   Spain                       1                      0.0
# 22/12/2015   Spain                       1                      0.0
# 23/12/2015   Spain                       1                      0.0
# 29/12/2015   Spain                       1                      0.0
# 23/03/2016   Spain                       1                      0.0
#
#             Male Cases  Female Cases  Boys  Girls  Adult Male  Adult Female  \
# Date
# 10/10/2014         0.6           0.4  0.18   0.12        0.36          0.24
# 15/10/2014         0.6           0.4  0.18   0.12        0.36          0.24
# 17/10/2014         0.6           0.4  0.18   0.12        0.36          0.24
# 22/10/2014         0.6           0.4  0.18   0.12        0.36          0.24
# 25/10/2014         0.6           0.4  0.18   0.12        0.36          0.24
# ...                ...           ...   ...    ...         ...           ...
# 17/12/2015         0.6           0.4  0.18   0.12        0.36          0.24
# 22/12/2015         0.6           0.4  0.18   0.12        0.36          0.24
# 23/12/2015         0.6           0.4  0.18   0.12        0.36          0.24
# 29/12/2015         0.6           0.4  0.18   0.12        0.36          0.24
# 23/03/2016         0.6           0.4  0.18   0.12        0.36          0.24
#
#             Old Male  Old Female
# Date
# 10/10/2014      0.06        0.04
# 15/10/2014      0.06        0.04
# 17/10/2014      0.06        0.04
# 22/10/2014      0.06        0.04
# 25/10/2014      0.06        0.04
# ...              ...         ...
# 17/12/2015      0.06        0.04
# 22/12/2015      0.06        0.04
# 23/12/2015      0.06        0.04
# 29/12/2015      0.06        0.04
# 23/03/2016      0.06        0.04
#
# [243 rows x 11 columns]

# %%
ESP.head()
# Out:
#            Country  No. of confirmed cases  No. of confirmed deaths  \
# Date
# 10/10/2014   Spain                       1                      0.0
# 15/10/2014   Spain                       1                      0.0
# 17/10/2014   Spain                       1                      0.0
# 22/10/2014   Spain                       1                      0.0
# 25/10/2014   Spain                       1                      0.0
#
#             Male Cases  Female Cases  Boys  Girls  Adult Male  Adult Female  \
# Date
# 10/10/2014         0.6           0.4  0.18   0.12        0.36          0.24
# 15/10/2014         0.6           0.4  0.18   0.12        0.36          0.24
# 17/10/2014         0.6           0.4  0.18   0.12        0.36          0.24
# 22/10/2014         0.6           0.4  0.18   0.12        0.36          0.24
# 25/10/2014         0.6           0.4  0.18   0.12        0.36          0.24
#
#             Old Male  Old Female
# Date
# 10/10/2014      0.06        0.04
# 15/10/2014      0.06        0.04
# 17/10/2014      0.06        0.04
# 22/10/2014      0.06        0.04
# 25/10/2014      0.06        0.04

# %%
ESP.isnull().sum()
# Out:
# Country                    0
# No. of confirmed cases     0
# No. of confirmed deaths    0
# Male Cases                 0
# Female Cases               0
# Boys                       0
# Girls                      0
# Adult Male                 0
# Adult Female               0
# Old Male                   0
# Old Female                 0
# dtype: int64

# %%
Dates=ESP.index[0:-1:10]
NCC=ESP['No. of confirmed cases'][0:-1:10]
NCD=ESP['No. of confirmed deaths'][0:-1:10]

# %%
fig=plt.figure(figsize=(13,7))
plt.plot(Dates,NCC,"o--y",ms=2,label="Infectados")
plt.bar(Dates,NCC,color='yellow',alpha=0.4)
plt.plot(Dates,NCD,'o--g',ms=4,label='Decesos')
plt.bar(Dates,NCD,color='green',alpha=0.3)
plt.grid(color="gray",linewidth="2",ms=20)
plt.title("Avance del ébola en España")
plt.ylabel("Casos confirmados")
plt.xlabel("Periodo de tiempo")
plt.xticks(rotation=90,fontsize=7)#Fechas rotadas y tamaño de las fechas.
plt.legend()
plt.savefig("infectadosydecesos.png",dpi=300,format='png')
plt.show()

# %%
PIvsD=100*ESP['No. of confirmed deaths']/ESP['No. of confirmed cases']#Porcentaje de Infectados que terminaton en deceso
ESP["PIvsD"]=PIvsD
# Out:
# <ipython-input-12-ecfcad0fbe7a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ESP["PIvsD"]=PIvsD

# %%
ESP.head()
# Out:
#            Country  No. of confirmed cases  No. of confirmed deaths  \
# Date
# 10/10/2014   Spain                       1                      0.0
# 15/10/2014   Spain                       1                      0.0
# 17/10/2014   Spain                       1                      0.0
# 22/10/2014   Spain                       1                      0.0
# 25/10/2014   Spain                       1                      0.0
#
#             Male Cases  Female Cases  Boys  Girls  Adult Male  Adult Female  \
# Date
# 10/10/2014         0.6           0.4  0.18   0.12        0.36          0.24
# 15/10/2014         0.6           0.4  0.18   0.12        0.36          0.24
# 17/10/2014         0.6           0.4  0.18   0.12        0.36          0.24
# 22/10/2014         0.6           0.4  0.18   0.12        0.36          0.24
# 25/10/2014         0.6           0.4  0.18   0.12        0.36          0.24
#
#             Old Male  Old Female  PIvsD
# Date
# 10/10/2014      0.06        0.04    0.0
# 15/10/2014      0.06        0.04    0.0
# 17/10/2014      0.06        0.04    0.0
# 22/10/2014      0.06        0.04    0.0
# 25/10/2014      0.06        0.04    0.0

# %%
#Cantidad de los recuperados
recuperados=((100-PIvsD)/100)*ESP['No. of confirmed cases']
ESP["recuperados"]=recuperados

#Porcentaje de recuperados
ESP["PR"]=(100-PIvsD)
# Out:
# <ipython-input-14-66c32144f332>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ESP["recuperados"]=recuperados
# <ipython-input-14-66c32144f332>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ESP["PR"]=(100-PIvsD)

# %%
PIvsD_mean=ESP["PIvsD"].mean()
PR_mean=ESP["PR"].mean()
porcentajes=[PIvsD_mean,PR_mean]
etiquetas=["PIvsD","PR"]

plt.pie(porcentajes,labels=etiquetas,autopct="%0.1f %%",colors=["blue","green"])
plt.axis("equal")
plt.title("Porcentaje de Recuperados vs Decesos")
plt.show()

# %%
G=ESP["Girls"][0:-1:15]
AF=ESP["Adult Female"][0:-1:15]
OF=ESP["Old Female"][0:-1:15]
Dates=ESP.index[0:-1:15]
fig=plt.figure(figsize=(20,6))
plt.bar(Dates,G,color="blue",alpha=0.8,label="Niñas")
plt.bar(Dates,AF,color="green",alpha=0.4,label="Adultas")
plt.bar(Dates,OF,color="cyan",alpha=0.8,label="Adultas Mayores")
plt.grid()
plt.title("Distribución del ébola en mujeres.")
plt.ylabel("Casos Confirmados.")
plt.xticks(rotation=90,fontsize=8)
plt.legend(loc="upper left",bbox_to_anchor=(1.02,0.5))
plt.savefig("Ébolaenmujeres.png",dpi=300,format="png")
plt.show()

# %%
G=ESP["Boys"][0:-1:15]
AF=ESP["Adult Male"][0:-1:15]
OF=ESP["Old Male"][0:-1:15]
Dates=ESP.index[0:-1:15]
fig=plt.figure(figsize=(20,6))
plt.bar(Dates,G,color="red",alpha=0.8,label="Niños")
plt.bar(Dates,AF,color="pink",alpha=0.4,label="Adultos")
plt.bar(Dates,OF,color="purple",alpha=0.8,label="Adultos Mayores")
plt.grid()
plt.title("Distribución del ébola en hombres.")
plt.ylabel("Casos Confirmados.")
plt.xticks(rotation=90,fontsize=8)
plt.legend(loc="upper left",bbox_to_anchor=(1.02,0.5))
plt.savefig("Ébolaenhombres.png",dpi=300,format="png")
plt.show()

# %%
Boys=ESP["Boys"].to_numpy()
ESP_Boys=pd.DataFrame({"Boys":Boys})
ESP_Boys.index=pd.to_datetime(ESP.index,format="%d/%m/%Y")
#ordenar fechas SL_Boys=SL.Boys.sort.index()

# %%
ESP_Boys
# Out:
#             Boys
# Date
# 2014-10-10  0.18
# 2014-10-15  0.18
# 2014-10-17  0.18
# 2014-10-22  0.18
# 2014-10-25  0.18
# ...          ...
# 2015-12-17  0.18
# 2015-12-22  0.18
# 2015-12-23  0.18
# 2015-12-29  0.18
# 2016-03-23  0.18
#
# [243 rows x 1 columns]

# %%
steps=57

data_train=ESP_Boys[:-steps]
data_test=ESP_Boys[-steps:]

# %%
print(f"Las fechas son {len(data_train)}")
# Out:
# Las fechas son 186

# %%
fig,ax=plt.subplots(figsize=(8,3))
data_train["Boys"].plot(ax=ax,label="train")
data_test["Boys"].plot(ax=ax,label="test")
ax.legend()
plt.show()

# %%
from skforecast.ForecasterAutoreg import ForecasterAutoreg
from sklearn.ensemble import RandomForestRegressor

forecaster=ForecasterAutoreg(
  regressor=RandomForestRegressor(random_state=123),
  lags=6
)

forecaster.fit(y=data_train["Boys"]) #predecir los datos

steps=57 #pedir los 57 datos que hbaía seleccionado
predicciones=forecaster.predict(steps=steps) #pronostica 57 pasos en el futuro

predicciones.index=data_test.index
# Out:
# /usr/local/lib/python3.10/dist-packages/skforecast/utils/utils.py:805: UserWarning: `y` has DatetimeIndex index but no frequency. Index is overwritten with a RangeIndex of step 1.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/skforecast/utils/utils.py:805: UserWarning: `y` has DatetimeIndex index but no frequency. Index is overwritten with a RangeIndex of step 1.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/skforecast/utils/utils.py:867: UserWarning: `last_window` has DatetimeIndex index but no frequency. Index is overwritten with a RangeIndex of step 1.
#   warnings.warn(

# %%
fig,ax=plt.subplots(figsize=(8,3))
#data_train["Boys"].plot(ax=ax,label="train")
data_test["Boys"].plot(ax=ax,label="test",lw=6,color="red") #datos reales
predicciones.plot(ax=ax,label="predicciones",lw=2,color="green") #datos calculados
ax.legend()
plt.grid()
plt.title("Modelo",fontsize=16)
plt.savefig("Datoscalculados.png",dpi=300,format="png")
plt.show()

# %%
import numpy as np
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

ESP_girls=ESP["Girls"]
ESP_girls=pd.DataFrame(ESP_girls)
future_days=50
ESP_girls["Prediction"]=ESP_girls["Girls"].shift(-future_days)

ESP_girls.tail()
# Out:
#             Girls  Prediction
# Date
# 17/12/2015   0.12         NaN
# 22/12/2015   0.12         NaN
# 23/12/2015   0.12         NaN
# 29/12/2015   0.12         NaN
# 23/03/2016   0.12         NaN

# %%
X = np.array(ESP_girls.drop(["Prediction"],1))[:-future_days]#deje libres los últimos 50
X.shape
y = np.array(ESP_girls["Prediction"])[:-future_days]
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
tree = DecisionTreeRegressor().fit(x_train,y_train) #Entrenarlo para obtener los valores que necesito pronosticados
lr = LinearRegression().fit(x_train,y_train)
x_future = ESP_girls.drop(["Prediction"],1)[:-future_days]
x_future = x_future.tail(future_days)
x_future = np.array(x_future)
x_future.shape
tree_prediction = tree.predict(x_future)
print(tree_prediction)
# Out:
# [0.12 0.12 0.12 0.12 0.12 0.12 0.12 0.12 0.12 0.12 0.12 0.12 0.12 0.12
#  0.12 0.12 0.12 0.12 0.12 0.12 0.12 0.12 0.12 0.12 0.12 0.12 0.12 0.12
#  0.12 0.12 0.12 0.12 0.12 0.12 0.12 0.12 0.12 0.12 0.12 0.12 0.12 0.12
#  0.12 0.12 0.12 0.12 0.12 0.12 0.12 0.12]
# <ipython-input-26-5566c3c089ca>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X = np.array(ESP_girls.drop(["Prediction"],1))[:-future_days]#deje libres los últimos 50
# <ipython-input-26-5566c3c089ca>:7: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   x_future = ESP_girls.drop(["Prediction"],1)[:-future_days]

# %%
predictions = tree_prediction
valid = ESP_girls[X.shape[0]:]
valid
# Out:
#             Girls  Prediction
# Date
# 18/09/2015   0.12         NaN
# 21/09/2015   0.12         NaN
# 22/09/2015   0.12         NaN
# 23/09/2015   0.12         NaN
# 24/09/2015   0.12         NaN
# 25/09/2015   0.12         NaN
# 28/09/2015   0.12         NaN
# 29/09/2015   0.12         NaN
# 30/09/2015   0.12         NaN
# 01/10/2015   0.12         NaN
# 02/10/2015   0.12         NaN
# 05/10/2015   0.12         NaN
# 06/10/2015   0.12         NaN
# 07/10/2015   0.12         NaN
# 08/10/2015   0.12         NaN
# 09/10/2015   0.12         NaN
# 13/10/2015   0.12         NaN
# 15/10/2015   0.12         NaN
# 16/10/2015   0.12         NaN
# 20/10/2015   0.12         NaN
# 22/10/2015   0.12         NaN
# 23/10/2015   0.12         NaN
# 26/10/2015   0.12         NaN
# 27/10/2015   0.12         NaN
# 29/10/2015   0.12         NaN
# 30/10/2015   0.12         NaN
# 03/11/2015   0.12         NaN
# 05/11/2015   0.12         NaN
# 06/11/2015   0.12         NaN
# 10/11/2015   0.12         NaN
# 11/11/2015   0.12         NaN
# 12/11/2015   0.12         NaN
# 16/11/2015   0.12         NaN
# 17/11/2015   0.12         NaN
# 20/11/2015   0.12         NaN
# 24/11/2015   0.12         NaN
# 26/11/2015   0.12         NaN
# 01/12/2015   0.12         NaN
# 02/12/2015   0.12         NaN
# 03/12/2015   0.12         NaN
# 09/12/2015   0.12         NaN
# 10/12/2015   0.12         NaN
# 11/12/2015   0.12         NaN
# 15/12/2015   0.12         NaN
# 16/12/2015   0.12         NaN
# 17/12/2015   0.12         NaN
# 22/12/2015   0.12         NaN
# 23/12/2015   0.12         NaN
# 29/12/2015   0.12         NaN
# 23/03/2016   0.12         NaN

# %%
valid['Predictions'] = predictions
valid
# Out:
# <ipython-input-28-d3e11ce66c00>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = predictions
#             Girls  Prediction  Predictions
# Date
# 18/09/2015   0.12         NaN         0.12
# 21/09/2015   0.12         NaN         0.12
# 22/09/2015   0.12         NaN         0.12
# 23/09/2015   0.12         NaN         0.12
# 24/09/2015   0.12         NaN         0.12
# 25/09/2015   0.12         NaN         0.12
# 28/09/2015   0.12         NaN         0.12
# 29/09/2015   0.12         NaN         0.12
# 30/09/2015   0.12         NaN         0.12
# 01/10/2015   0.12         NaN         0.12
# 02/10/2015   0.12         NaN         0.12
# 05/10/2015   0.12         NaN         0.12
# 06/10/2015   0.12         NaN         0.12
# 07/10/2015   0.12         NaN         0.12
# 08/10/2015   0.12         NaN         0.12
# 09/10/2015   0.12         NaN         0.12
# 13/10/2015   0.12         NaN         0.12
# 15/10/2015   0.12         NaN         0.12
# 16/10/2015   0.12         NaN         0.12
# 20/10/2015   0.12         NaN         0.12
# 22/10/2015   0.12         NaN         0.12
# 23/10/2015   0.12         NaN         0.12
# 26/10/2015   0.12         NaN         0.12
# 27/10/2015   0.12         NaN         0.12
# 29/10/2015   0.12         NaN         0.12
# 30/10/2015   0.12         NaN         0.12
# 03/11/2015   0.12         NaN         0.12
# 05/11/2015   0.12         NaN         0.12
# 06/11/2015   0.12         NaN         0.12
# 10/11/2015   0.12         NaN         0.12
# 11/11/2015   0.12         NaN         0.12
# 12/11/2015   0.12         NaN         0.12
# 16/11/2015   0.12         NaN         0.12
# 17/11/2015   0.12         NaN         0.12
# 20/11/2015   0.12         NaN         0.12
# 24/11/2015   0.12         NaN         0.12
# 26/11/2015   0.12         NaN         0.12
# 01/12/2015   0.12         NaN         0.12
# 02/12/2015   0.12         NaN         0.12
# 03/12/2015   0.12         NaN         0.12
# 09/12/2015   0.12         NaN         0.12
# 10/12/2015   0.12         NaN         0.12
# 11/12/2015   0.12         NaN         0.12
# 15/12/2015   0.12         NaN         0.12
# 16/12/2015   0.12         NaN         0.12
# 17/12/2015   0.12         NaN         0.12
# 22/12/2015   0.12         NaN         0.12
# 23/12/2015   0.12         NaN         0.12
# 29/12/2015   0.12         NaN         0.12
# 23/03/2016   0.12         NaN         0.12

# %%
plt.figure(figsize=(16,8))
plt.title("Modelo con árboles",fontsize=14)
plt.plot(valid['Girls'],'-r',lw=6)
plt.plot(valid['Predictions'],'-k',lw=2)
plt.legend([ "Valid", 'Predicted'])
plt.show()
